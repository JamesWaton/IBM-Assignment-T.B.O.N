# %% [markdown]
# # Peer-graded Assignment: Capstone Project - The Battle of Neighborhoods (Week 1)
# # Where to open a Greek food shop.

# %% [markdown]
# ### ******Please leave a comment on why you marked my work the way you did so i can improve !!!

# %% [markdown]
# # Week 1

# %% [markdown]
# ### Problem: Greek chef Looking for a place to open a resturant in Australia   and doesn't know where the best place is.
# ### Target Audience: Greek Chef's or anyone looking to open a greek shop

# %% [markdown]
# # With in this data analysis i am helping a greek chef with where to open a new Greek resturant in australia

# %% [markdown]
# ### In this analysis I will be looking where to open it in melbourne as 44% of greek imagrents in australia live there.
# #### The top 5 subers with a greek population is Whittlesea, Darebin, Moreland, Manningham, Monash.
# ref https://liveinmelbourne.vic.gov.au/discover/multicultural-communities/greek

# %% [markdown]
# ### First i will be finding what suberbs have the most greek resturants then from there i will chose the suberb with the least greek resturants.
# ### So there will be less competion. I will be gathering this through the foursquare api that we have been using in past projects.

# %% [markdown]
# # Methodology section:
# ## 1. connect to foursquare api
# ## 2. Find High street of each suberb and search a 2 km radius to try find Greek Resturants
# ## 3. Normalize resluts to put it into into a visible dataframe.
# ## 4. Results section.
# ## 5. Discussion section.
# ## 6. Conclusion

# %% [markdown]
# # Week 2

# %% [markdown]
#  ### The data i will be using will be from foursquare. I will be getting data of greek resturants 2 KM of aroud the main street of each top Greek suberbs in Melbourne Vic, Australia.
# ### Once i have a list of how many Greek food stores there are i can then compare them to one another to see what suberb has the least stores.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
#      |████████████████████████████████| 79 kB 9.4 MB/s  eta 0:00:01
# ...
#   Created wheel for folium: filename=folium-0.5.0-py3-none-any.whl size=76240 sha256=8a05aa05d0853c4026e81ec5ee10b693796282cecbba4a1e9facb55bbad6cfe6
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/b2/2f/2c/109e446b990d663ea5ce9b078b5e7c1a9c45cca91f377080f8
# Successfully built folium
# ...
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'QQPAHXOSXEIDONSTPPODXHGWZGZJVAAJ24J13ZCKH1RYN0RZ' # your Foursquare ID
CLIENT_SECRET = 'LYCGK4OSHI25S1ZJIVAOLF1GZEJDVN2EILWLUT3HN5ZJVUVF' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: QQPAHXOSXEIDONSTPPODXHGWZGZJVAAJ24J13ZCKH1RYN0RZ
# CLIENT_SECRET:LYCGK4OSHI25S1ZJIVAOLF1GZEJDVN2EILWLUT3HN5ZJVUVF

# %% [markdown]
# ## Locations
#
# Monash:
# State Route 13
# Clayton VIC 3168
# -37.911327, 145.140978
#
#
# Whittlesea:
# Church St
# Whittlesea VIC 3757
# -37.513563, 145.117728
#
#
# Darebin:
# 50-56 High St
# Preston VIC 3072
# -37.749739, 145.002105
#
#
# Moreland:
# 492-450 State Route 55
# Coburg VIC 3058
# -37.742396, 144.966368
#
#
# Manningham:
# Macedon Rd
# Templestowe Lower VIC 3107
# -37.772603, 145.112359

# %% [markdown]
# # Error Occers as havent run all the code above as i am just editing and adding comments as i Failed due to lack of discription

# %%
#Getting location
# Error Occers as havent run all the code above as i am just editing and adding comments as i Failed due to lack of discription 
address = 'State Route 13, Clayton, VIC'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e34906b48d56> in <module>
#       1 #Getting location
#       2 address = 'State Route 13, Clayton, VIC'
# ----> 3 geolocator = Nominatim(user_agent="foursquare_agent")
#       4 location = geolocator.geocode(address)
#       5 latitude = location.latitude
#
# NameError: name 'Nominatim' is not defined

# %%
search_query = 'Greek'
radius = 2000
print(search_query + ' .... OK!')
# Out:
# Greek .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=QQPAHXOSXEIDONSTPPODXHGWZGZJVAAJ24J13ZCKH1RYN0RZ&client_secret=LYCGK4OSHI25S1ZJIVAOLF1GZEJDVN2EILWLUT3HN5ZJVUVF&ll=-37.9173212,145.1304242&v=20180604&query=Greek&radius=2000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fadbb7d66505c5f6f69b7d5'},
#  'response': {'venues': [{'id': '5afffadc9ba3e5002cb72e7d',
#     'name': 'Greek Europa',
#     'location': {'lat': -37.927763,
#      'lng': 145.119419,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.927763,
#        'lng': 145.119419}],
#      'distance': 1511,
#      'postalCode': '3168',
#      'cc': 'AU',
#      'city': 'Clayton',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['Clayton VIC 3168', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1605221245',
#     'hasPerk': False},
#    {'id': '4db161d8cda14b702a433f6b',
#     'name': 'Greek Orthodox Curch Clayton',
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                          name  \
# 0  5afffadc9ba3e5002cb72e7d                  Greek Europa
# 1  4db161d8cda14b702a433f6b  Greek Orthodox Curch Clayton
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1605221245    False
# 1  [{'id': '4bf58dd8d48988d132941735', 'name': 'C...  v-1605221245    False
#
#    location.lat  location.lng  \
# 0    -37.927763    145.119419
# 1    -37.928552    145.114902
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': -37.927763, 'lng'...               1511
# 1  [{'label': 'display', 'lat': -37.9285521675006...               1849
#
# ...

# %% [markdown]
# # Two resturants for Monash

# %%
#Now for Whittlesea                     


address = 'Church St, Whittlesea, VIC'
geolocator = Nominatim(user_agent="foursquare_agent")
whittlesea_location = geolocator.geocode(address)
whittlesea_latitude = location.latitude
whittlesea_longitude = location.longitude
print(latitude, longitude)


search_query = 'Greek'
radius = 2000
print(search_query + ' .... OK!')
# Out:
# -37.5132325 145.1178143
# Greek .... OK!

# %%
whittlesea_url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, whittlesea_latitude, whittlesea_longitude, VERSION, search_query, radius, LIMIT)
whittlesea_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=QQPAHXOSXEIDONSTPPODXHGWZGZJVAAJ24J13ZCKH1RYN0RZ&client_secret=LYCGK4OSHI25S1ZJIVAOLF1GZEJDVN2EILWLUT3HN5ZJVUVF&ll=-37.5132325,145.1178143&v=20180604&query=Greek&radius=2000&limit=30'

# %%
whittlesea_results = requests.get(whittlesea_url).json()
whittlesea_results
# Out:
# {'meta': {'code': 200, 'requestId': '5fadbed6d91d7d1d49331265'},
#  'response': {'venues': []}}

# %% [markdown]
# # None in Whittlsea

# %%
# Now for Darebin
address = '50-56 High St, Preston, VIC'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)


search_query = 'Greek'
radius = 2000
print(search_query + ' .... OK!')


url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

Darebin_results = requests.get(url).json()
Darebin_results

# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
Darebin_dataframe = json_normalize(venues)
Darebin_dataframe.head()
# Out:
# -37.749913875000004 145.0022382
# Greek .... OK!
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:25: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                     name  \
# 0  5685073c498e6916fb20a75a      Greek Kitchen & Bar
# 1  5c8cae06f870fd002c8bd8d4        Greek Street Food
# 2  4b3c7ad7f964a5209e8425e3  Natalia's Greek Cuisine
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10e941735', 'name': 'G...  v-1605221815    False
# 1  [{'id': '4bf58dd8d48988d10e941735', 'name': 'G...  v-1605221815    False
# 2  [{'id': '4bf58dd8d48988d10e941735', 'name': 'G...  v-1605221815    False
#
#    location.address  location.lat  location.lng  \
# 0  845-847 High St.    -37.755022    145.001121
# 1   794 High Street    -37.754161    145.001527
# 2       437 High St    -37.767380    144.999020
#
# ...

# %% [markdown]
# # Darebin has 3

# %%
#Now for Moreland

#Moreland
#492-450 State Route 55
#Coburg VIC 3058
#-37.742396, 144.966368

address = '492-450 State, Coburg, VIC'
geolocator = Nominatim(user_agent="foursquare_agent")
Moreland_location = geolocator.geocode(address)
Moreland_latitude = -37.742396
Moreland_longitude = 144.966368
print(latitude, longitude)

#2KM RADIUS
search_query = 'Greek'
radius = 2000
print(search_query + ' .... OK!')


Moreland_url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, Moreland_latitude, Moreland_longitude, VERSION, search_query, radius, LIMIT)
Moreland_url

Moreland_results = requests.get(Moreland_url).json()
Moreland_results
# Out:
# -37.7449752 144.9643314
# Greek .... OK!
# {'meta': {'code': 200, 'requestId': '5fadc06e33f6626c688ccad0'},
#  'response': {'venues': [{'id': '4db1650c5da32cf2df5a618e',
#     'name': 'Greek Orthodox Church Of Coburg And Pascoe Vale',
#     'location': {'lat': -37.743013812169906,
#      'lng': 144.96362776207593,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.743013812169906,
#        'lng': 144.96362776207593}],
#      'distance': 250,
#      'cc': 'AU',
#      'state': 'Victoria',
#      'country': 'Australia',
#      'formattedAddress': ['Pascoe Vale South VIC', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1605222510',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
Moreland_venues = Moreland_results['response']['venues']

# tranform venues into a dataframe
Moreland_dataframe = json_normalize(Moreland_venues)
Moreland_dataframe.head()
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                                             name  \
# 0  4db1650c5da32cf2df5a618e  Greek Orthodox Church Of Coburg And Pascoe Vale
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d132941735', 'name': 'C...  v-1605222510    False
#
#    location.lat  location.lng  \
# 0    -37.743014    144.963628
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': -37.7430138121699...                250
#
#   location.cc location.state location.country  \
# 0          AU       Victoria        Australia
#
#             location.formattedAddress
# 0  [Pascoe Vale South VIC, Australia]

# %% [markdown]
# # One in Moreland

# %%
#Now for Manningham

#Manningham_ 
#Macedon Rd
#Templestowe Lower VIC 3107
#-37.772603, 145.112359


address = 'Macedon Rd, Templestowe Lower, VIC'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
Manningham_latitude = location.latitude
Manningham_longitude = location.longitude
print(latitude, longitude)

#2KM RADIUS
search_query = 'Greek'
radius = 2000
print(search_query + ' .... OK!')


Manningham_url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, Manningham_latitude, Manningham_longitude, VERSION, search_query, radius, LIMIT)
Manningham_url

Manningham_results = requests.get(Manningham_url).json()
Manningham_results

# %%
# assign relevant part of JSON to venues
Manningham_venues = Manningham_results['response']['venues']

# tranform venues into a dataframe
Manningham_dataframe = json_normalize(Manningham_venues)
Manningham_dataframe.head()
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                          name  \
# 0  4cc7c8b3be874688ae9b80af  Orlando's Greek Delicatessen
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...  v-1605222727    False
#
#   location.address  location.lat  location.lng  \
# 0      6 Stutt Ave    -37.786121    145.107124
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': -37.786121, 'lng'...               2099
#
#   location.postalCode location.cc location.city location.state  \
# 0                3108          AU     Doncaster            VIC
#
#   location.country                     location.formattedAddress
# 0        Australia  [6 Stutt Ave, Doncaster VIC 3108, Australia]

# %% [markdown]
# # One in Manningham

# %% [markdown]
# # Result:
#
# Monash:2
#
# Whittlesea:0
#
# Darebin:3
#
# Moreland:1
#
# Manningham:1

# %% [markdown]
# # Discussion
# ### Although there is none in Whitlesea if the chef had a certain style he best in cooking in e.g. DInner, Take aways or Lunch.
# ### He could go to another suberb that has a higher population where there is no other resturant with that style of Greek food.

# %% [markdown]
# # Conclusion
# #### With my the data gathered I would predict to have a greek resturnt in the Northern Suberb of Whittlesea as the are no resturants there yet it is in the top five places in melbourne with a high Greek population.
